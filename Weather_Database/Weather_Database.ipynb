# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 746

# %%
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lata
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | araguacu
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | tecoanapa
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | saint-pierre
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | liling
# Processing Record 16 of Set 1 | kunming
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | broome
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | smidovich
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | rosetown
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | klaksvik
# Processing Record 30 of Set 1 | ahipara
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | nouadhibou
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | saint anthony
# Processing Record 36 of Set 1 | ilulissat
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | roma
# Processing Record 41 of Set 1 | high rock
# Processing Record 42 of Set 1 | pangnirtung
# Processing Record 43 of Set 1 | tazovskiy
# Processing Record 44 of Set 1 | mazara del vallo
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | clarksburg
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | salalah
# Processing Record 50 of Set 1 | berlevag
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 2 | cao bang
# Processing Record 4 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 2 | bonavista
# Processing Record 6 of Set 2 | ikwiriri
# Processing Record 7 of Set 2 | samarai
# Processing Record 8 of Set 2 | saraj
# Processing Record 9 of Set 2 | wau
# Processing Record 10 of Set 2 | sakaiminato
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | la ronge
# Processing Record 13 of Set 2 | kruisfontein
# Processing Record 14 of Set 2 | port-cartier
# Processing Record 15 of Set 2 | fortuna
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | sibolga
# Processing Record 18 of Set 2 | college
# Processing Record 19 of Set 2 | nanortalik
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | tomatlan
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | atambua
# Processing Record 26 of Set 2 | sur
# Processing Record 27 of Set 2 | taoudenni
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | hasaki
# Processing Record 30 of Set 2 | praia da vitoria
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | terneuzen
# Processing Record 37 of Set 2 | turochak
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | bac lieu
# Processing Record 40 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 2 | olafsvik
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | kalmar
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | kavaratti
# Processing Record 49 of Set 2 | boa vista
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | hirna
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | meulaboh
# Processing Record 4 of Set 3 | aklavik
# Processing Record 5 of Set 3 | puerto madryn
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | zverinogolovskoye
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | pechory
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | hamilton
# Processing Record 12 of Set 3 | naron
# Processing Record 13 of Set 3 | constitucion
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | san ramon de la nueva oran
# Processing Record 16 of Set 3 | bluff
# Processing Record 17 of Set 3 | atuona
# Processing Record 18 of Set 3 | liverpool
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | bonoua
# Processing Record 23 of Set 3 | kristiansund
# Processing Record 24 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 25 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 3 | te anau
# Processing Record 27 of Set 3 | shakiso
# Processing Record 28 of Set 3 | pobe
# Processing Record 29 of Set 3 | clyde river
# Processing Record 30 of Set 3 | desaguadero
# Processing Record 31 of Set 3 | caravelas
# Processing Record 32 of Set 3 | banda aceh
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | bitung
# Processing Record 35 of Set 3 | itarema
# Processing Record 36 of Set 3 | harper
# Processing Record 37 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 3 | tongzi
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | adrar
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | coolum beach
# Processing Record 43 of Set 3 | ust-kut
# Processing Record 44 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | changying
# Processing Record 46 of Set 3 | san joaquin
# Processing Record 47 of Set 3 | damghan
# Processing Record 48 of Set 3 | flinders
# Processing Record 49 of Set 3 | garowe
# Processing Record 50 of Set 3 | buala
# Processing Record 1 of Set 4 | mokhsogollokh
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 4 | the valley
# Processing Record 5 of Set 4 | yuxia
# Processing Record 6 of Set 4 | portland
# Processing Record 7 of Set 4 | ilo
# Processing Record 8 of Set 4 | poum
# Processing Record 9 of Set 4 | gushikawa
# Processing Record 10 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 4 | jacmel
# Processing Record 12 of Set 4 | new norfolk
# Processing Record 13 of Set 4 | sangmelima
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | kavieng
# Processing Record 16 of Set 4 | darien
# Processing Record 17 of Set 4 | ketchikan
# Processing Record 18 of Set 4 | bara
# Processing Record 19 of Set 4 | bukama
# Processing Record 20 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 4 | caninde
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | maryborough
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 4 | kloulklubed
# Processing Record 29 of Set 4 | avarua
# Processing Record 30 of Set 4 | igrim
# Processing Record 31 of Set 4 | goreloye
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | lambarene
# Processing Record 34 of Set 4 | souillac
# Processing Record 35 of Set 4 | hastings
# Processing Record 36 of Set 4 | qaanaaq
# Processing Record 37 of Set 4 | nurota
# Processing Record 38 of Set 4 | san carlos
# Processing Record 39 of Set 4 | port blair
# Processing Record 40 of Set 4 | tibati
# Processing Record 41 of Set 4 | tura
# Processing Record 42 of Set 4 | carutapera
# Processing Record 43 of Set 4 | vicuna
# Processing Record 44 of Set 4 | pochutla
# Processing Record 45 of Set 4 | bontang
# Processing Record 46 of Set 4 | swellendam
# Processing Record 47 of Set 4 | manokwari
# Processing Record 48 of Set 4 | rudnogorsk
# Processing Record 49 of Set 4 | provideniya
# Processing Record 50 of Set 4 | boshnyakovo
# Processing Record 1 of Set 5 | misratah
# Processing Record 2 of Set 5 | moose factory
# Processing Record 3 of Set 5 | port augusta
# Processing Record 4 of Set 5 | luderitz
# Processing Record 5 of Set 5 | kampene
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | wasilla
# Processing Record 11 of Set 5 | mopipi
# Processing Record 12 of Set 5 | solnechnyy
# Processing Record 13 of Set 5 | port elizabeth
# Processing Record 14 of Set 5 | gardan diwal
# City not found. Skipping...
# Processing Record 15 of Set 5 | richards bay
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | samarinda
# Processing Record 18 of Set 5 | bukachacha
# Processing Record 19 of Set 5 | fort nelson
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | carballo
# Processing Record 22 of Set 5 | juneau
# Processing Record 23 of Set 5 | vangaindrano
# Processing Record 24 of Set 5 | wanaka
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | chom bung
# City not found. Skipping...
# Processing Record 27 of Set 5 | beringovskiy
# Processing Record 28 of Set 5 | siverek
# Processing Record 29 of Set 5 | mahon
# Processing Record 30 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 5 | stettler
# Processing Record 32 of Set 5 | yarada
# Processing Record 33 of Set 5 | agua verde
# Processing Record 34 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 5 | vancouver
# Processing Record 36 of Set 5 | pevek
# Processing Record 37 of Set 5 | namatanai
# Processing Record 38 of Set 5 | makakilo city
# Processing Record 39 of Set 5 | hvide sande
# Processing Record 40 of Set 5 | bandarbeyla
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | lyubashivka
# Processing Record 43 of Set 5 | bilma
# Processing Record 44 of Set 5 | sorong
# Processing Record 45 of Set 5 | luwuk
# Processing Record 46 of Set 5 | lincoln
# Processing Record 47 of Set 5 | hailey
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | pascagoula
# Processing Record 1 of Set 6 | harlingen
# Processing Record 2 of Set 6 | necochea
# Processing Record 3 of Set 6 | suleja
# Processing Record 4 of Set 6 | hobyo
# Processing Record 5 of Set 6 | husavik
# Processing Record 6 of Set 6 | vila velha
# Processing Record 7 of Set 6 | labuhan
# Processing Record 8 of Set 6 | puerto ayora
# Processing Record 9 of Set 6 | mecca
# Processing Record 10 of Set 6 | jacareacanga
# Processing Record 11 of Set 6 | tafresh
# Processing Record 12 of Set 6 | los llanos de aridane
# Processing Record 13 of Set 6 | trairi
# Processing Record 14 of Set 6 | kushiro
# Processing Record 15 of Set 6 | russell
# Processing Record 16 of Set 6 | komsomolskiy
# Processing Record 17 of Set 6 | shubarshi
# Processing Record 18 of Set 6 | santiago de cao
# Processing Record 19 of Set 6 | itarare
# Processing Record 20 of Set 6 | canon city
# Processing Record 21 of Set 6 | rassvet
# Processing Record 22 of Set 6 | buin
# Processing Record 23 of Set 6 | tilichiki
# Processing Record 24 of Set 6 | bambanglipuro
# Processing Record 25 of Set 6 | grindavik
# Processing Record 26 of Set 6 | durango
# Processing Record 27 of Set 6 | santa vitoria do palmar
# Processing Record 28 of Set 6 | paraiso
# Processing Record 29 of Set 6 | burnie
# Processing Record 30 of Set 6 | lompoc
# Processing Record 31 of Set 6 | tire
# Processing Record 32 of Set 6 | henties bay
# Processing Record 33 of Set 6 | newport
# Processing Record 34 of Set 6 | biak
# Processing Record 35 of Set 6 | hami
# Processing Record 36 of Set 6 | broken hill
# Processing Record 37 of Set 6 | khilok
# Processing Record 38 of Set 6 | aktau
# Processing Record 39 of Set 6 | bodo
# Processing Record 40 of Set 6 | port-gentil
# Processing Record 41 of Set 6 | pasni
# Processing Record 42 of Set 6 | glubokoe
# City not found. Skipping...
# Processing Record 43 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | iskateley
# Processing Record 46 of Set 6 | novokruchininskiy
# Processing Record 47 of Set 6 | khasan
# Processing Record 48 of Set 6 | santa rosa
# Processing Record 49 of Set 6 | ulladulla
# Processing Record 50 of Set 6 | gurskoye
# City not found. Skipping...
# Processing Record 1 of Set 7 | prachuap khiri khan
# Processing Record 2 of Set 7 | aviemore
# Processing Record 3 of Set 7 | manyana
# Processing Record 4 of Set 7 | tyukalinsk
# Processing Record 5 of Set 7 | bambous virieux
# Processing Record 6 of Set 7 | charagua
# Processing Record 7 of Set 7 | mukhen
# Processing Record 8 of Set 7 | catuday
# Processing Record 9 of Set 7 | tahoua
# Processing Record 10 of Set 7 | sawakin
# Processing Record 11 of Set 7 | sitka
# Processing Record 12 of Set 7 | grande-riviere
# City not found. Skipping...
# Processing Record 13 of Set 7 | cerro azul
# Processing Record 14 of Set 7 | tarut
# Processing Record 15 of Set 7 | ukiah
# Processing Record 16 of Set 7 | beyneu
# Processing Record 17 of Set 7 | sao filipe
# Processing Record 18 of Set 7 | registro
# Processing Record 19 of Set 7 | uruacu
# Processing Record 20 of Set 7 | foshan
# Processing Record 21 of Set 7 | krasnyy chikoy
# Processing Record 22 of Set 7 | gweta
# Processing Record 23 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 7 | kosovska mitrovica
# Processing Record 25 of Set 7 | goma
# Processing Record 26 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 7 | mahanoro
# Processing Record 28 of Set 7 | raudeberg
# Processing Record 29 of Set 7 | kanker
# Processing Record 30 of Set 7 | oga
# Processing Record 31 of Set 7 | dukat
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | teguldet
# Processing Record 34 of Set 7 | tautira
# Processing Record 35 of Set 7 | sao gabriel da cachoeira
# Processing Record 36 of Set 7 | ridgecrest
# Processing Record 37 of Set 7 | caracuaro
# Processing Record 38 of Set 7 | rapu-rapu
# Processing Record 39 of Set 7 | ostrovnoy
# Processing Record 40 of Set 7 | puri
# Processing Record 41 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 42 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 7 | black river
# Processing Record 44 of Set 7 | dongsheng
# Processing Record 45 of Set 7 | pisco
# Processing Record 46 of Set 7 | kapit
# Processing Record 47 of Set 7 | calceta
# Processing Record 48 of Set 7 | comodoro rivadavia
# Processing Record 49 of Set 7 | geraldton
# Processing Record 50 of Set 7 | camargo
# Processing Record 1 of Set 8 | sunnyside
# Processing Record 2 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 8 | camacupa
# Processing Record 4 of Set 8 | avare
# Processing Record 5 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 8 | constantine
# Processing Record 7 of Set 8 | aitape
# Processing Record 8 of Set 8 | joetsu
# Processing Record 9 of Set 8 | yinchuan
# Processing Record 10 of Set 8 | chingirlau
# Processing Record 11 of Set 8 | arvika
# Processing Record 12 of Set 8 | augusto correa
# Processing Record 13 of Set 8 | hinton
# Processing Record 14 of Set 8 | arona
# Processing Record 15 of Set 8 | pemangkat
# Processing Record 16 of Set 8 | nemuro
# Processing Record 17 of Set 8 | lagoa
# Processing Record 18 of Set 8 | novoagansk
# Processing Record 19 of Set 8 | rioja
# Processing Record 20 of Set 8 | uyuni
# Processing Record 21 of Set 8 | turukhansk
# Processing Record 22 of Set 8 | leningradskiy
# Processing Record 23 of Set 8 | callaway
# Processing Record 24 of Set 8 | ati
# Processing Record 25 of Set 8 | pagudpud
# Processing Record 26 of Set 8 | xai-xai
# Processing Record 27 of Set 8 | baruun-urt
# Processing Record 28 of Set 8 | nouakchott
# Processing Record 29 of Set 8 | ciudad bolivar
# Processing Record 30 of Set 8 | gillette
# Processing Record 31 of Set 8 | ikom
# Processing Record 32 of Set 8 | seoul
# Processing Record 33 of Set 8 | mount isa
# Processing Record 34 of Set 8 | marystown
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | imbituba
# Processing Record 37 of Set 8 | ulety
# Processing Record 38 of Set 8 | muros
# Processing Record 39 of Set 8 | rexburg
# Processing Record 40 of Set 8 | itamaraju
# Processing Record 41 of Set 8 | kalemie
# Processing Record 42 of Set 8 | vaitape
# Processing Record 43 of Set 8 | sarkand
# Processing Record 44 of Set 8 | kaeo
# Processing Record 45 of Set 8 | ballina
# Processing Record 46 of Set 8 | gigmoto
# Processing Record 47 of Set 8 | ust-karsk
# Processing Record 48 of Set 8 | pontes e lacerda
# Processing Record 49 of Set 8 | nueva loja
# Processing Record 50 of Set 8 | jhang
# Processing Record 1 of Set 9 | kansk
# Processing Record 2 of Set 9 | huarmey
# Processing Record 3 of Set 9 | iqaluit
# Processing Record 4 of Set 9 | najran
# Processing Record 5 of Set 9 | sobolevo
# Processing Record 6 of Set 9 | port macquarie
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | chongwe
# Processing Record 9 of Set 9 | touros
# Processing Record 10 of Set 9 | iglino
# Processing Record 11 of Set 9 | acara
# Processing Record 12 of Set 9 | isangel
# Processing Record 13 of Set 9 | abha
# Processing Record 14 of Set 9 | paamiut
# Processing Record 15 of Set 9 | longyearbyen
# Processing Record 16 of Set 9 | nakamura
# Processing Record 17 of Set 9 | shitanjing
# Processing Record 18 of Set 9 | sterling
# Processing Record 19 of Set 9 | puerto colombia
# Processing Record 20 of Set 9 | balsas
# Processing Record 21 of Set 9 | miraflores
# Processing Record 22 of Set 9 | botwood
# Processing Record 23 of Set 9 | zaysan
# Processing Record 24 of Set 9 | waingapu
# Processing Record 25 of Set 9 | petrovac
# Processing Record 26 of Set 9 | huron
# Processing Record 27 of Set 9 | auki
# Processing Record 28 of Set 9 | wichita falls
# Processing Record 29 of Set 9 | naze
# Processing Record 30 of Set 9 | viedma
# Processing Record 31 of Set 9 | saint george
# Processing Record 32 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 9 | ayapel
# Processing Record 34 of Set 9 | athabasca
# Processing Record 35 of Set 9 | havre-saint-pierre
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | sambava
# Processing Record 38 of Set 9 | sabang
# Processing Record 39 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 9 | cockburn town
# Processing Record 41 of Set 9 | tineo
# Processing Record 42 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 9 | simao
# Processing Record 45 of Set 9 | zambezi
# Processing Record 46 of Set 9 | suntar
# Processing Record 47 of Set 9 | tucuman
# Processing Record 48 of Set 9 | santa maria
# Processing Record 49 of Set 9 | west plains
# Processing Record 50 of Set 9 | karla
# Processing Record 1 of Set 10 | thunder bay
# Processing Record 2 of Set 10 | palmer
# Processing Record 3 of Set 10 | jalu
# Processing Record 4 of Set 10 | lodwar
# Processing Record 5 of Set 10 | nikki
# Processing Record 6 of Set 10 | qaqortoq
# Processing Record 7 of Set 10 | elat
# Processing Record 8 of Set 10 | mims
# Processing Record 9 of Set 10 | zouxian
# City not found. Skipping...
# Processing Record 10 of Set 10 | ranchuelo
# Processing Record 11 of Set 10 | heihe
# Processing Record 12 of Set 10 | talnakh
# Processing Record 13 of Set 10 | seymchan
# Processing Record 14 of Set 10 | sivas
# Processing Record 15 of Set 10 | port moresby
# Processing Record 16 of Set 10 | colares
# Processing Record 17 of Set 10 | hervey bay
# Processing Record 18 of Set 10 | hirara
# Processing Record 19 of Set 10 | faya
# Processing Record 20 of Set 10 | maunabo
# Processing Record 21 of Set 10 | maoming
# Processing Record 22 of Set 10 | alice springs
# Processing Record 23 of Set 10 | marawi
# Processing Record 24 of Set 10 | zasheyek
# Processing Record 25 of Set 10 | dingli
# Processing Record 26 of Set 10 | san juan
# Processing Record 27 of Set 10 | vardo
# Processing Record 28 of Set 10 | do gonbadan
# Processing Record 29 of Set 10 | ilheus
# Processing Record 30 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 10 | quelimane
# Processing Record 32 of Set 10 | padang
# Processing Record 33 of Set 10 | honiara
# Processing Record 34 of Set 10 | mackay
# Processing Record 35 of Set 10 | moron
# Processing Record 36 of Set 10 | alofi
# Processing Record 37 of Set 10 | kahului
# Processing Record 38 of Set 10 | taiyuan
# Processing Record 39 of Set 10 | batemans bay
# Processing Record 40 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 10 | sidi ali
# Processing Record 42 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 10 | dudinka
# Processing Record 44 of Set 10 | tadine
# Processing Record 45 of Set 10 | sisophon
# Processing Record 46 of Set 10 | abonnema
# Processing Record 47 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 10 | tuatapere
# Processing Record 49 of Set 10 | ocos
# Processing Record 50 of Set 10 | sakakah
# Processing Record 1 of Set 11 | korla
# Processing Record 2 of Set 11 | guerrero
# Processing Record 3 of Set 11 | malakoff
# Processing Record 4 of Set 11 | tsumeb
# Processing Record 5 of Set 11 | praia
# Processing Record 6 of Set 11 | denpasar
# Processing Record 7 of Set 11 | gravelbourg
# Processing Record 8 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 11 | chiang rai
# Processing Record 10 of Set 11 | nybro
# Processing Record 11 of Set 11 | mosquera
# Processing Record 12 of Set 11 | pointe michel
# Processing Record 13 of Set 11 | moyale
# Processing Record 14 of Set 11 | tutoia
# Processing Record 15 of Set 11 | mudgee
# Processing Record 16 of Set 11 | porto torres
# Processing Record 17 of Set 11 | peniche
# Processing Record 18 of Set 11 | ambulu
# Processing Record 19 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 11 | senanga
# Processing Record 22 of Set 11 | vygonichi
# Processing Record 23 of Set 11 | oloron-sainte-marie
# Processing Record 24 of Set 11 | wawa
# Processing Record 25 of Set 11 | belaya gora
# Processing Record 26 of Set 11 | vagur
# Processing Record 27 of Set 11 | acapulco
# Processing Record 28 of Set 11 | mount gambier
# Processing Record 29 of Set 11 | roxas
# Processing Record 30 of Set 11 | mogadishu
# Processing Record 31 of Set 11 | concordia
# Processing Record 32 of Set 11 | havoysund
# Processing Record 33 of Set 11 | saint-francois
# Processing Record 34 of Set 11 | terrace
# Processing Record 35 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 36 of Set 11 | saint-augustin
# Processing Record 37 of Set 11 | ishinomaki
# Processing Record 38 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 39 of Set 11 | ponta delgada
# Processing Record 40 of Set 11 | borogontsy
# Processing Record 41 of Set 11 | nha trang
# Processing Record 42 of Set 11 | kafue
# Processing Record 43 of Set 11 | minsk
# Processing Record 44 of Set 11 | bogorodskoye
# Processing Record 45 of Set 11 | neiafu
# Processing Record 46 of Set 11 | xiuyan
# Processing Record 47 of Set 11 | camocim
# Processing Record 48 of Set 11 | mokrous
# Processing Record 49 of Set 11 | buraydah
# Processing Record 50 of Set 11 | bojnurd
# Processing Record 1 of Set 12 | medicine hat
# Processing Record 2 of Set 12 | lamu
# Processing Record 3 of Set 12 | wooster
# Processing Record 4 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 12 | oranjemund
# Processing Record 6 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 7 of Set 12 | kharp
# Processing Record 8 of Set 12 | old saybrook
# Processing Record 9 of Set 12 | swan hill
# Processing Record 10 of Set 12 | elban
# Processing Record 11 of Set 12 | plouzane
# Processing Record 12 of Set 12 | kieta
# Processing Record 13 of Set 12 | ferme-neuve
# Processing Record 14 of Set 12 | namie
# Processing Record 15 of Set 12 | porto murtinho
# Processing Record 16 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 17 of Set 12 | sept-iles
# Processing Record 18 of Set 12 | nome
# Processing Record 19 of Set 12 | nishihara
# Processing Record 20 of Set 12 | rundu
# Processing Record 21 of Set 12 | senneterre
# Processing Record 22 of Set 12 | mantua
# Processing Record 23 of Set 12 | evensk
# Processing Record 24 of Set 12 | jiaozuo
# Processing Record 25 of Set 12 | coracora
# Processing Record 26 of Set 12 | tubuala
# Processing Record 27 of Set 12 | duz
# City not found. Skipping...
# Processing Record 28 of Set 12 | bisira
# Processing Record 29 of Set 12 | haines junction
# Processing Record 30 of Set 12 | canto do buriti
# Processing Record 31 of Set 12 | yuzhnyy
# Processing Record 32 of Set 12 | karaton
# Processing Record 33 of Set 12 | tulun
# Processing Record 34 of Set 12 | mayo
# Processing Record 35 of Set 12 | tabou
# Processing Record 36 of Set 12 | vanimo
# Processing Record 37 of Set 12 | kununurra
# Processing Record 38 of Set 12 | san cristobal
# Processing Record 39 of Set 12 | bocaranga
# City not found. Skipping...
# Processing Record 40 of Set 12 | oistins
# Processing Record 41 of Set 12 | shakawe
# Processing Record 42 of Set 12 | pyapon
# Processing Record 43 of Set 12 | laem sing
# Processing Record 44 of Set 12 | san carlos de bariloche
# Processing Record 45 of Set 12 | snyder
# Processing Record 46 of Set 12 | kisangani
# Processing Record 47 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 12 | nyurba
# Processing Record 49 of Set 12 | paranaiba
# Processing Record 50 of Set 12 | poplar bluff
# Processing Record 1 of Set 13 | mangrol
# Processing Record 2 of Set 13 | vila franca do campo
# Processing Record 3 of Set 13 | bima
# Processing Record 4 of Set 13 | high level
# Processing Record 5 of Set 13 | espera feliz
# Processing Record 6 of Set 13 | hun
# Processing Record 7 of Set 13 | tingrela
# City not found. Skipping...
# Processing Record 8 of Set 13 | sterlibashevo
# Processing Record 9 of Set 13 | lakatoro
# Processing Record 10 of Set 13 | gimli
# Processing Record 11 of Set 13 | araouane
# Processing Record 12 of Set 13 | dobsina
# Processing Record 13 of Set 13 | neuquen
# Processing Record 14 of Set 13 | kristiinankaupunki
# Processing Record 15 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 13 | boden
# Processing Record 17 of Set 13 | alekseyevka
# Processing Record 18 of Set 13 | cayhagan
# Processing Record 19 of Set 13 | peruibe
# Processing Record 20 of Set 13 | tambo
# Processing Record 21 of Set 13 | kachug
# Processing Record 22 of Set 13 | safaga
# Processing Record 23 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 24 of Set 13 | derzhavinsk
# Processing Record 25 of Set 13 | laizhou
# Processing Record 26 of Set 13 | gatton
# Processing Record 27 of Set 13 | vao
# Processing Record 28 of Set 13 | zalantun
# Processing Record 29 of Set 13 | bahia honda
# Processing Record 30 of Set 13 | talcahuano
# Processing Record 31 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 32 of Set 13 | nuuk
# Processing Record 33 of Set 13 | platteville
# Processing Record 34 of Set 13 | kembe
# Processing Record 35 of Set 13 | strezhevoy
# Processing Record 36 of Set 13 | pokhara
# Processing Record 37 of Set 13 | coromandel
# Processing Record 38 of Set 13 | juba
# Processing Record 39 of Set 13 | beloha
# Processing Record 40 of Set 13 | mangaratiba
# Processing Record 41 of Set 13 | presidencia roque saenz pena
# Processing Record 42 of Set 13 | zhigansk
# Processing Record 43 of Set 13 | kutulik
# Processing Record 44 of Set 13 | coihaique
# Processing Record 45 of Set 13 | ascension
# Processing Record 46 of Set 13 | sao joao da barra
# Processing Record 47 of Set 13 | rokytne
# Processing Record 48 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 13 | matameye
# City not found. Skipping...
# Processing Record 50 of Set 13 | vallenar
# Processing Record 1 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 14 | heze
# Processing Record 3 of Set 14 | atar
# Processing Record 4 of Set 14 | zhangye
# Processing Record 5 of Set 14 | smithers
# Processing Record 6 of Set 14 | qasigiannguit
# Processing Record 7 of Set 14 | koslan
# Processing Record 8 of Set 14 | hofn
# Processing Record 9 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 14 | las margaritas
# Processing Record 11 of Set 14 | lagdo
# Processing Record 12 of Set 14 | zhezkazgan
# Processing Record 13 of Set 14 | bilibino
# Processing Record 14 of Set 14 | saint-georges
# Processing Record 15 of Set 14 | nasipit
# Processing Record 16 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 17 of Set 14 | margate
# Processing Record 18 of Set 14 | marsh harbour
# Processing Record 19 of Set 14 | yangambi
# Processing Record 20 of Set 14 | banepa
# Processing Record 21 of Set 14 | lithakia
# Processing Record 22 of Set 14 | neftekumsk
# Processing Record 23 of Set 14 | yar-sale
# Processing Record 24 of Set 14 | rocha
# Processing Record 25 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 14 | boguchany
# Processing Record 27 of Set 14 | starodub
# Processing Record 28 of Set 14 | angra
# City not found. Skipping...
# Processing Record 29 of Set 14 | okhotsk
# Processing Record 30 of Set 14 | paraopeba
# Processing Record 31 of Set 14 | koumac
# Processing Record 32 of Set 14 | maragogi
# Processing Record 33 of Set 14 | fengxian
# Processing Record 34 of Set 14 | praxedis guerrero
# Processing Record 35 of Set 14 | egvekinot
# Processing Record 36 of Set 14 | ixtapa
# Processing Record 37 of Set 14 | alakurtti
# Processing Record 38 of Set 14 | riverton
# Processing Record 39 of Set 14 | ust-maya
# Processing Record 40 of Set 14 | pinsk
# Processing Record 41 of Set 14 | paita
# Processing Record 42 of Set 14 | sisimiut
# Processing Record 43 of Set 14 | vestmannaeyjar
# Processing Record 44 of Set 14 | weinan
# Processing Record 45 of Set 14 | lorengau
# Processing Record 46 of Set 14 | borovichi
# Processing Record 47 of Set 14 | port hardy
# Processing Record 48 of Set 14 | eganville
# Processing Record 49 of Set 14 | qingdao
# Processing Record 50 of Set 14 | kirakira
# Processing Record 1 of Set 15 | bairnsdale
# Processing Record 2 of Set 15 | biltine
# Processing Record 3 of Set 15 | gazanjyk
# Processing Record 4 of Set 15 | tera
# Processing Record 5 of Set 15 | chara
# Processing Record 6 of Set 15 | nagua
# Processing Record 7 of Set 15 | manta
# Processing Record 8 of Set 15 | okakarara
# Processing Record 9 of Set 15 | mapiripan
# Processing Record 10 of Set 15 | beaumont
# Processing Record 11 of Set 15 | fiche
# Processing Record 12 of Set 15 | cootamundra
# Processing Record 13 of Set 15 | taltal
# Processing Record 14 of Set 15 | christchurch
# Processing Record 15 of Set 15 | brae
# Processing Record 16 of Set 15 | rochegda
# Processing Record 17 of Set 15 | sovetskiy
# Processing Record 18 of Set 15 | kita
# Processing Record 19 of Set 15 | grand gaube
# Processing Record 20 of Set 15 | porto real
# Processing Record 21 of Set 15 | port shepstone
# Processing Record 22 of Set 15 | la grande
# Processing Record 23 of Set 15 | itacarambi
# Processing Record 24 of Set 15 | lenki
# City not found. Skipping...
# Processing Record 25 of Set 15 | masalli
# Processing Record 26 of Set 15 | baghdad
# Processing Record 27 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 28 of Set 15 | vero beach
# Processing Record 29 of Set 15 | bardiyah
# Processing Record 30 of Set 15 | mulege
# Processing Record 31 of Set 15 | puqi
# Processing Record 32 of Set 15 | shimanovsk
# Processing Record 33 of Set 15 | arlit
# Processing Record 34 of Set 15 | dubbo
# Processing Record 35 of Set 15 | belen
# Processing Record 36 of Set 15 | lazaro cardenas
# Processing Record 37 of Set 15 | dingle
# Processing Record 38 of Set 15 | kalmunai
# Processing Record 39 of Set 15 | katha
# City not found. Skipping...
# Processing Record 40 of Set 15 | banamba
# Processing Record 41 of Set 15 | general roca
# Processing Record 42 of Set 15 | mumford
# Processing Record 43 of Set 15 | oriximina
# Processing Record 44 of Set 15 | fort-shevchenko
# Processing Record 45 of Set 15 | marshall
# Processing Record 46 of Set 15 | ust-ilimsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
df = pd.DataFrame(city_data)
df.head(5)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Lata      PT  40.1629   -8.3327     61.81        71          89
# 1  Punta Arenas      CL -53.1500  -70.9167     44.71        70          75
# 2     Busselton      AU -33.6500  115.3333     65.52        49         100
# 3       Rikitea      PF -23.1203 -134.9692     73.51        84         100
# 4      Araguacu      BR -12.9306  -49.8264     88.93        52          75
#
#    Wind Speed Current Description
# 0        5.91     overcast clouds
# 1        3.44       broken clouds
# 2       12.39          light rain
# 3        9.93          light rain
# 4        3.15       broken clouds

# %%
export_csv = "WeatherPy_Database.csv"
df.to_csv(export_csv, index_label = 'City_ID')
